# %% [markdown]
# ## Loading The Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Loading The Dataset

# %%
dataset = pd.read_csv('dataset.csv')

# %% [markdown]
# ## Printing The Dataset

# %%
dataset
# Out:
#        Customer_id  age          job  marital            education  default  \
# 0                1   56     services  married          high.school       no
# 1                2   45     services  married             basic.9y  unknown
# 2                3   59       admin.  married  professional.course       no
# 3                4   41  blue-collar  married              unknown  unknown
# 4                5   24   technician   single  professional.course       no
# ...            ...  ...          ...      ...                  ...      ...
# 37079        37080   73      retired  married  professional.course       no
# 37080        37081   46  blue-collar  married  professional.course       no
# 37081        37082   56      retired  married    university.degree       no
# 37082        37083   44   technician  married  professional.course       no
# 37083        37084   74      retired  married  professional.course       no
#
#       housing loan        City_Name  State_Name  ... nr.employed    contact  \
# 0          no  yes        Henderson    Kentucky  ...      5191.0  telephone
# 1          no   no        Henderson    Kentucky  ...      5191.0  telephone
# 2          no   no      Los Angeles  California  ...      5191.0  telephone
# 3          no   no  Fort Lauderdale     Florida  ...      5191.0  telephone
# 4         yes   no  Fort Lauderdale     Florida  ...      5191.0  telephone
# ...       ...  ...              ...         ...  ...         ...        ...
# 37079     yes   no    New York City    New York  ...      4963.6   cellular
# 37080      no   no    New York City    New York  ...      4963.6   cellular
# 37081     yes   no    New York City    New York  ...      4963.6   cellular
# 37082      no   no       Scottsdale     Arizona  ...      4963.6   cellular
# 37083     yes   no         Amarillo       Texas  ...      4963.6   cellular
#
#        month  day_of_week  duration  campaign pdays previous     poutcome    y
# 0        may          mon       307         1   999        0  nonexistent   no
# 1        may          mon       198         1   999        0  nonexistent   no
# 2        may          mon       139         1   999        0  nonexistent   no
# 3        may          mon       217         1   999        0  nonexistent   no
# 4        may          mon       380         1   999        0  nonexistent   no
# ...      ...          ...       ...       ...   ...      ...          ...  ...
# 37079    nov          fri       334         1   999        0  nonexistent  yes
# 37080    nov          fri       383         1   999        0  nonexistent   no
# 37081    nov          fri       189         2   999        0  nonexistent   no
# 37082    nov          fri       442         1   999        0  nonexistent  yes
# 37083    nov          fri       239         3   999        1      failure   no
#
# [37084 rows x 25 columns]

# %% [markdown]
# ## Printing The Datatypes Of The Dataset

# %%
dataset.dtypes
# Out:
# Customer_id         int64
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# City_Name          object
# State_Name         object
# Region_Name        object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# y                  object
# dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37084 entries, 0 to 37083
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer_id     37084 non-null  int64
#  1   age             37084 non-null  int64
#  2   job             37084 non-null  object
#  3   marital         37084 non-null  object
#  4   education       37084 non-null  object
#  5   default         37084 non-null  object
#  6   housing         37084 non-null  object
#  7   loan            37084 non-null  object
#  8   City_Name       37084 non-null  object
#  9   State_Name      37084 non-null  object
#  10  Region_Name     37084 non-null  object
#  11  emp.var.rate    37084 non-null  float64
#  12  cons.price.idx  37084 non-null  float64
#  13  cons.conf.idx   37084 non-null  float64
#  14  euribor3m       37084 non-null  float64
#  15  nr.employed     37084 non-null  float64
#  16  contact         37084 non-null  object
#  17  month           37084 non-null  object
#  18  day_of_week     37084 non-null  object
#  19  duration        37084 non-null  int64
#  20  campaign        37084 non-null  int64
#  21  pdays           37084 non-null  int64
#  22  previous        37084 non-null  int64
#  23  poutcome        37084 non-null  object
#  24  y               37084 non-null  object
# dtypes: float64(5), int64(6), object(14)
# memory usage: 7.1+ MB

# %%
dataset.describe()
# Out:
#         Customer_id           age  emp.var.rate  cons.price.idx  \
# count  37084.000000  37084.000000  37084.000000    37084.000000
# mean   18542.500000     40.042714      0.082669       93.576076
# std    10705.373028     10.432965      1.568997        0.578493
# min        1.000000     17.000000     -3.400000       92.201000
# 25%     9271.750000     32.000000     -1.800000       93.075000
# 50%    18542.500000     38.000000      1.100000       93.749000
# 75%    27813.250000     47.000000      1.400000       93.994000
# max    37084.000000     98.000000      1.400000       94.767000
#
#        cons.conf.idx     euribor3m   nr.employed      duration      campaign  \
# count   37084.000000  37084.000000  37084.000000  37084.000000  37084.000000
# mean      -40.505183      3.621668   5167.058664    258.237946      2.569545
# std         4.622045      1.733972     72.196605    258.730909      2.770611
# min       -50.800000      0.634000   4963.600000      0.000000      1.000000
# 25%       -42.700000      1.344000   5099.100000    102.000000      1.000000
# 50%       -41.800000      4.857000   5191.000000    180.000000      2.000000
# 75%       -36.400000      4.961000   5228.100000    319.250000      3.000000
# max       -26.900000      5.045000   5228.100000   4918.000000     56.000000
#
#               pdays      previous
# count  37084.000000  37084.000000
# mean     962.530849      0.172986
# std      186.773063      0.495681
# min        0.000000      0.000000
# 25%      999.000000      0.000000
# 50%      999.000000      0.000000
# 75%      999.000000      0.000000
# max      999.000000      7.000000

# %% [markdown]
# ## Printing The Number Of Rows And Columns

# %%
dataset.shape
# Out:
# (37084, 25)

# %% [markdown]
# ## Checking For Null Values

# %%
dataset.isnull().sum()
# Out:
# Customer_id       0
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# City_Name         0
# State_Name        0
# Region_Name       0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# y                 0
# dtype: int64

# %% [markdown]
# ## Modifying The 'education' Column

# %%
dataset['education'].value_counts()
# Out:
# university.degree      10971
# high.school             8542
# basic.9y                5421
# professional.course     4746
# basic.4y                3765
# basic.6y                2074
# unknown                 1549
# illiterate                16
# Name: education, dtype: int64

# %%
# Define a mapping dictionary for replacement
replacement_dict = {
    'basic.4y': 'middle school',
    'basic.6y': 'middle school',
    'basic.9y': 'middle school'
}

# Replace the values in the 'education' column based on the dictionary
dataset['education'] = dataset['education'].replace(replacement_dict)

# %%
dataset['education'].value_counts()
# Out:
# middle school          11260
# university.degree      10971
# high.school             8542
# professional.course     4746
# unknown                 1549
# illiterate                16
# Name: education, dtype: int64

# %%
dataset
# Out:
#        Customer_id  age          job  marital            education  default  \
# 0                1   56     services  married          high.school       no
# 1                2   45     services  married        middle school  unknown
# 2                3   59       admin.  married  professional.course       no
# 3                4   41  blue-collar  married              unknown  unknown
# 4                5   24   technician   single  professional.course       no
# ...            ...  ...          ...      ...                  ...      ...
# 37079        37080   73      retired  married  professional.course       no
# 37080        37081   46  blue-collar  married  professional.course       no
# 37081        37082   56      retired  married    university.degree       no
# 37082        37083   44   technician  married  professional.course       no
# 37083        37084   74      retired  married  professional.course       no
#
#       housing loan        City_Name  State_Name  ... nr.employed    contact  \
# 0          no  yes        Henderson    Kentucky  ...      5191.0  telephone
# 1          no   no        Henderson    Kentucky  ...      5191.0  telephone
# 2          no   no      Los Angeles  California  ...      5191.0  telephone
# 3          no   no  Fort Lauderdale     Florida  ...      5191.0  telephone
# 4         yes   no  Fort Lauderdale     Florida  ...      5191.0  telephone
# ...       ...  ...              ...         ...  ...         ...        ...
# 37079     yes   no    New York City    New York  ...      4963.6   cellular
# 37080      no   no    New York City    New York  ...      4963.6   cellular
# 37081     yes   no    New York City    New York  ...      4963.6   cellular
# 37082      no   no       Scottsdale     Arizona  ...      4963.6   cellular
# 37083     yes   no         Amarillo       Texas  ...      4963.6   cellular
#
#        month  day_of_week  duration  campaign pdays previous     poutcome    y
# 0        may          mon       307         1   999        0  nonexistent   no
# 1        may          mon       198         1   999        0  nonexistent   no
# 2        may          mon       139         1   999        0  nonexistent   no
# 3        may          mon       217         1   999        0  nonexistent   no
# 4        may          mon       380         1   999        0  nonexistent   no
# ...      ...          ...       ...       ...   ...      ...          ...  ...
# 37079    nov          fri       334         1   999        0  nonexistent  yes
# 37080    nov          fri       383         1   999        0  nonexistent   no
# 37081    nov          fri       189         2   999        0  nonexistent   no
# 37082    nov          fri       442         1   999        0  nonexistent  yes
# 37083    nov          fri       239         3   999        1      failure   no
#
# [37084 rows x 25 columns]

# %% [markdown]
# ## Modifying The 'pdays' Column

# %%
dataset.loc[dataset['pdays'] == 999, 'pdays'] = 0
dataset['pdays'].value_counts()
# Out:
# 0     35734
# 3       398
# 6       361
# 4       105
# 9        57
# 2        56
# 12       54
# 7        51
# 10       46
# 5        43
# 13       34
# 11       28
# 1        25
# 14       20
# 15       19
# 8        18
# 16       11
# 17        8
# 18        4
# 22        3
# 19        3
# 21        2
# 25        1
# 26        1
# 27        1
# 20        1
# Name: pdays, dtype: int64

# %% [markdown]
# ## Modifying The 'duration' Column

# %%
call_duration_segment = []
for i in dataset['duration']:
    if i >=0 and i < 100:
        call_duration_segment.append('0')
    elif i >= 100 and i < 200:
        call_duration_segment.append('1')
    elif i >= 200 and i < 300:
        call_duration_segment.append('2')
    elif i >= 300 and i < 400:
        call_duration_segment.append('3')
    elif i >= 400 and i < 500:
        call_duration_segment.append('4')
    elif i >= 500 and i < 600:
        call_duration_segment.append('5')
    elif i >= 600 and i < 700:
        call_duration_segment.append('6')
    elif i >= 700 and i < 800:
        call_duration_segment.append('7')
    elif i >= 800 and i < 900:
        call_duration_segment.append('8')
    elif i >= 900 and i < 1000:
        call_duration_segment.append('9')
    elif i >= 1000 and i < 2000:
        call_duration_segment.append('10')
    elif i >= 2000 and i < 3000:
        call_duration_segment.append('11')
    elif i >= 3000 and i < 4000:
        call_duration_segment.append('12')
    else: 
        call_duration_segment.append('13')

dataset['call_duration_segment'] = call_duration_segment

# %%
dataset = dataset.astype({"call_duration_segment": int})

# %%
dataset.drop(columns='duration',inplace=True)

# %%
dataset
# Out:
#        Customer_id  age          job  marital            education  default  \
# 0                1   56     services  married          high.school       no
# 1                2   45     services  married        middle school  unknown
# 2                3   59       admin.  married  professional.course       no
# 3                4   41  blue-collar  married              unknown  unknown
# 4                5   24   technician   single  professional.course       no
# ...            ...  ...          ...      ...                  ...      ...
# 37079        37080   73      retired  married  professional.course       no
# 37080        37081   46  blue-collar  married  professional.course       no
# 37081        37082   56      retired  married    university.degree       no
# 37082        37083   44   technician  married  professional.course       no
# 37083        37084   74      retired  married  professional.course       no
#
#       housing loan        City_Name  State_Name  ... nr.employed    contact  \
# 0          no  yes        Henderson    Kentucky  ...      5191.0  telephone
# 1          no   no        Henderson    Kentucky  ...      5191.0  telephone
# 2          no   no      Los Angeles  California  ...      5191.0  telephone
# 3          no   no  Fort Lauderdale     Florida  ...      5191.0  telephone
# 4         yes   no  Fort Lauderdale     Florida  ...      5191.0  telephone
# ...       ...  ...              ...         ...  ...         ...        ...
# 37079     yes   no    New York City    New York  ...      4963.6   cellular
# 37080      no   no    New York City    New York  ...      4963.6   cellular
# 37081     yes   no    New York City    New York  ...      4963.6   cellular
# 37082      no   no       Scottsdale     Arizona  ...      4963.6   cellular
# 37083     yes   no         Amarillo       Texas  ...      4963.6   cellular
#
#        month  day_of_week  campaign  pdays previous     poutcome    y  \
# 0        may          mon         1      0        0  nonexistent   no
# 1        may          mon         1      0        0  nonexistent   no
# 2        may          mon         1      0        0  nonexistent   no
# 3        may          mon         1      0        0  nonexistent   no
# 4        may          mon         1      0        0  nonexistent   no
# ...      ...          ...       ...    ...      ...          ...  ...
# 37079    nov          fri         1      0        0  nonexistent  yes
# 37080    nov          fri         1      0        0  nonexistent   no
# 37081    nov          fri         2      0        0  nonexistent   no
# 37082    nov          fri         1      0        0  nonexistent  yes
# 37083    nov          fri         3      0        1      failure   no
#
#        call_duration_segment
# 0                          3
# 1                          1
# 2                          1
# 3                          2
# 4                          3
# ...                      ...
# 37079                      3
# 37080                      3
# 37081                      1
# 37082                      4
# 37083                      2
#
# [37084 rows x 25 columns]

# %% [markdown]
# ## Call Duration

# %%
plt.figure(figsize=(11, 5))                                                                                                                                                                                                
plt.title('Call Duration Distribution')
plt.xticks(rotation=90)
sns.set_context("paper", font_scale=0.93)   
abs_values = dataset['call_duration_segment'].value_counts().values
ax = sns.countplot(x=dataset['call_duration_segment'],order=dataset['call_duration_segment'].value_counts().index)
ax.bar_label(container=ax.containers[0],labels=abs_values,padding=3)
plt.show()

# %%
diff_categ_count=dataset['call_duration_segment'].value_counts()
group_table=dataset.groupby(['call_duration_segment','y']).size().astype(float)
for categ in group_table.index.levels[0]:
    for income in group_table[categ].index:
        group_table[categ][income]=group_table[categ][income]/diff_categ_count[categ]*100
group_table.unstack().plot(kind='bar',stacked=True)
plt.ylabel('Percentage of Subscription Rate')
plt.title('Subscription Rate by Call Duration')
# Out:
# Text(0.5, 1.0, 'Subscription Rate by Call Duration')

# %% [markdown]
# ## Job

# %%
plt.figure(figsize=(11, 2.5))                                                                                                                                                                                                
plt.title('Education Type Distribution')
plt.xticks(rotation=90)
sns.set_context("paper", font_scale=0.93)   
sns.countplot(x=dataset['job'],order=dataset['job'].value_counts().index)
plt.show()

# %%
diff_categ_count=dataset['job'].value_counts()
group_table=dataset.groupby(['job','y']).size().astype(float)
for categ in group_table.index.levels[0]:
    for income in group_table[categ].index:
        group_table[categ][income]=group_table[categ][income]/diff_categ_count[categ]*100
group_table.unstack().plot(kind='bar',stacked=True)
plt.ylabel('Percentage of Subscription Rate')
plt.title('Subscription Rate by Job Type')
# Out:
# Text(0.5, 1.0, 'Subscription Rate by Job Type')

# %% [markdown]
# ## Marital Status

# %%
palette_color = sns.color_palette('pastel')[0:5]
explode = [0.02, 0.02, 0.02, 0.02]
plt.pie(dataset['marital'].value_counts().values, labels=dataset['marital'].value_counts().index, colors=palette_color, autopct='%.0f%%', explode=explode)
plt.show()

# %%
diff_categ_count=dataset['marital'].value_counts()
group_table=dataset.groupby(['marital','y']).size().astype(float)
for categ in group_table.index.levels[0]:
    for income in group_table[categ].index:
        group_table[categ][income]=group_table[categ][income]/diff_categ_count[categ]*100
group_table.unstack().plot(kind='bar',stacked=True)
plt.ylabel('Percentage of Subscription Rate')
plt.title('Subscription Rate by Marital Status')
# Out:
# Text(0.5, 1.0, 'Subscription Rate by Marital Status')

# %% [markdown]
# ## Education Type

# %%
plt.figure(figsize=(11, 2.5))                                                                                                                                                                                                
plt.title('Education Type Distribution')
plt.xticks(rotation=90)
sns.set_context("paper", font_scale=0.93)   
sns.countplot(x=dataset['education'],order=dataset['education'].value_counts().index)
plt.show()

# %%
diff_categ_count=dataset['education'].value_counts()
group_table=dataset.groupby(['education','y']).size().astype(float)
for categ in group_table.index.levels[0]:
    for income in group_table[categ].index:
        group_table[categ][income]=group_table[categ][income]/diff_categ_count[categ]*100
group_table.unstack().plot(kind='bar',stacked=True)
plt.ylabel('Percentage of Subscription Rate')
plt.title('Subscription Rate by Education Type')
# Out:
# Text(0.5, 1.0, 'Subscription Rate by Education Type')

# %% [markdown]
# ## Credit

# %%
plt.figure(figsize=(11, 2.5))                                                                                                                                                                                                
plt.title('Credit Type Distribution')
plt.xticks(rotation=90)
sns.set_context("paper", font_scale=0.93)   
sns.countplot(x=dataset['default'],order=dataset['default'].value_counts().index)
plt.show()

# %%
diff_categ_count=dataset['default'].value_counts()
group_table=dataset.groupby(['default','y']).size().astype(float)
for categ in group_table.index.levels[0]:
    for income in group_table[categ].index:
        group_table[categ][income]=group_table[categ][income]/diff_categ_count[categ]*100
group_table.unstack().plot(kind='bar',stacked=True)
plt.ylabel('Percentage of Subscription Rate')
plt.title('Subscription Rate by Credit Type')
# Out:
# Text(0.5, 1.0, 'Subscription Rate by Credit Type')

# %% [markdown]
# ## Housing Loan Type Distribution

# %% [markdown]
# Housing column represents whether a given customer has a housing loan or not.

# %%
plt.figure(figsize=(11, 2.5))                                                                                                                                                                                                
plt.title('Housing Loan Type Distribution')
plt.xticks(rotation=90)
sns.set_context("paper", font_scale=0.93)   
sns.countplot(x=dataset['housing'],order=dataset['housing'].value_counts().index)
plt.show()

# %%
diff_categ_count=dataset['housing'].value_counts()
group_table=dataset.groupby(['housing','y']).size().astype(float)
for categ in group_table.index.levels[0]:
    for income in group_table[categ].index:
        group_table[categ][income]=group_table[categ][income]/diff_categ_count[categ]*100
group_table.unstack().plot(kind='bar',stacked=True)
plt.ylabel('Percentage of Subscription Rate')
plt.title('Subscription Rate by Housing Loan Type')
# Out:
# Text(0.5, 1.0, 'Subscription Rate by Housing Loan Type')

# %% [markdown]
# ## Loan Type

# %%
plt.figure(figsize=(11, 2.5))                                                                                                                                                                                                
plt.title('Housing Loan Type Distribution')
plt.xticks(rotation=90)
sns.set_context("paper", font_scale=0.93)   
sns.countplot(x=dataset['loan'],order=dataset['loan'].value_counts().index)
plt.show()

# %%
diff_categ_count=dataset['loan'].value_counts()
group_table=dataset.groupby(['loan','y']).size().astype(float)
for categ in group_table.index.levels[0]:
    for income in group_table[categ].index:
        group_table[categ][income]=group_table[categ][income]/diff_categ_count[categ]*100
group_table.unstack().plot(kind='bar',stacked=True)
plt.ylabel('Percentage of Subscription Rate')
plt.title('Subscription Rate by Loan Type')
# Out:
# Text(0.5, 1.0, 'Subscription Rate by Loan Type')

# %% [markdown]
# ## Contact Type

# %%
plt.figure(figsize=(11, 2.5))                                                                                                                                                                                                
plt.title('Contact Type Distribution')
plt.xticks(rotation=90)
sns.set_context("paper", font_scale=0.93)   
sns.countplot(x=dataset['contact'],order=dataset['contact'].value_counts().index)
plt.show()

# %%
diff_categ_count=dataset['contact'].value_counts()
group_table=dataset.groupby(['contact','y']).size().astype(float)
for categ in group_table.index.levels[0]:
    for income in group_table[categ].index:
        group_table[categ][income]=group_table[categ][income]/diff_categ_count[categ]*100
group_table.unstack().plot(kind='bar',stacked=True)
plt.ylabel('Percentage of Subscription Rate')
plt.title('Subscription Rate by Contact Type')
# Out:
# Text(0.5, 1.0, 'Subscription Rate by Contact Type')

# %% [markdown]
# ## poutcome

# %%
plt.figure(figsize=(11, 2.5))                                                                                                                                                                                                
plt.title('Distribution Based on Previous Campaign Outcome')
plt.xticks(rotation=90)
sns.set_context("paper", font_scale=0.93)   
sns.countplot(x=dataset['poutcome'],order=dataset['poutcome'].value_counts().index)
plt.show()

# %%
diff_categ_count=dataset['poutcome'].value_counts()
group_table=dataset.groupby(['poutcome','y']).size().astype(float)
for categ in group_table.index.levels[0]:
    for income in group_table[categ].index:
        group_table[categ][income]=group_table[categ][income]/diff_categ_count[categ]*100
group_table.unstack().plot(kind='bar',stacked=True)
plt.ylabel('Percentage of Subscription Rate')
plt.title('Subscription Rate Based on Previous Campaign Outcome')
# Out:
# Text(0.5, 1.0, 'Subscription Rate Based on Previous Campaign Outcome')

# %% [markdown]
# ## State Wise Distribution

# %%
plt.figure(figsize=(11, 2.5))                                                                                                                                                                                                
plt.title('Distribution Based on State')
plt.xticks(rotation=90)
sns.set_context("paper", font_scale=0.93)   
sns.countplot(x=dataset['State_Name'],order=dataset['State_Name'].value_counts().index)
plt.show()

# %%
plt.figure(figsize=(20, 16))
diff_categ_count=dataset['State_Name'].value_counts()
group_table=dataset.groupby(['State_Name','y']).size().astype(float)
for categ in group_table.index.levels[0]:
    for income in group_table[categ].index:
        group_table[categ][income]=group_table[categ][income]/diff_categ_count[categ]*100
group_table.unstack().plot(kind='bar',stacked=True)
plt.ylabel('Percentage of Subscription Rate')
plt.title('Subscription Rate Based on State')
# Out:
# Text(0.5, 1.0, 'Subscription Rate Based on State')

# %% [markdown]
# ## Outlier Handling

# %%
plt.figure(figsize = (15, 30))
plt.style.use('seaborn-white')
ax=plt.subplot(521)
plt.boxplot(dataset['age'])
ax.set_title('age')
ax=plt.subplot(522)
plt.boxplot(dataset['campaign'])
ax.set_title('campaign')
ax=plt.subplot(524)
plt.boxplot(dataset['pdays'])
ax.set_title('pdays')
ax=plt.subplot(525)
plt.boxplot(dataset['previous'])
ax.set_title('previous')
ax=plt.subplot(526)
plt.boxplot(dataset['emp.var.rate'])
ax.set_title('Employee variation rate')
ax=plt.subplot(527)
plt.boxplot(dataset['cons.price.idx'])
ax.set_title('Consumer price index')
ax=plt.subplot(528)
plt.boxplot(dataset['cons.conf.idx'])
ax.set_title('Consumer confidence index')
ax=plt.subplot(529)
plt.boxplot(dataset['euribor3m'])
ax.set_title('euribor3m')
ax=plt.subplot(5,2,10)
plt.boxplot(dataset['nr.employed'])
ax.set_title('No of employees')
# Out:
# C:\Users\ishit\AppData\Local\Temp\ipykernel_15492\822211157.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')
# Text(0.5, 1.0, 'No of employees')

# %% [markdown]
# - Columns 'age', 'campaign', 'duration' have outliers.

# %%
numerical_features=['age','campaign']
for cols in numerical_features:
    Q1 = dataset[cols].quantile(0.25)
    Q3 = dataset[cols].quantile(0.75)
    IQR = Q3 - Q1     

    filter = (dataset[cols] >= Q1 - 1.5 * IQR) & (dataset[cols] <= Q3 + 1.5 *IQR)
    dataset=dataset.loc[filter]

# %%
plt.figure(figsize = (15, 10))
plt.style.use('seaborn-white')
ax=plt.subplot(221)
plt.boxplot(dataset['age'])
ax.set_title('age')
ax=plt.subplot(222)
plt.boxplot(dataset['campaign'])
ax.set_title('campaign')
# Out:
# C:\Users\ishit\AppData\Local\Temp\ipykernel_15492\2502648372.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')
# Text(0.5, 1.0, 'campaign')

# %% [markdown]
# ## Encoding The Columns

# %% [markdown]
# ### Frequency Encoding Of 'job', 'education', 'City_Names', 'State_Names' and 'Region_Names'

# %% [markdown]
# #### Job

# %%
dataset_job=dataset['job'].value_counts().to_dict()
dataset['job']=dataset['job'].map(dataset_job)

# %% [markdown]
# #### Education

# %%
dataset_ed=dataset['education'].value_counts().to_dict()
dataset['education']=dataset['education'].map(dataset_ed)

# %%
dataset
# Out:
#        Customer_id  age   job   marital  education  default housing loan  \
# 0                1   56  3332   married       8020       no      no  yes
# 1                2   45  3332   married      10380  unknown      no   no
# 2                3   59  8834   married       4422       no      no   no
# 3                4   41  7843   married       1413  unknown      no   no
# 4                5   24  5720    single       4422       no     yes   no
# ...            ...  ...   ...       ...        ...      ...     ...  ...
# 37077        37078   64  1095  divorced       4422       no     yes   no
# 37078        37079   37  8834   married      10229       no     yes   no
# 37080        37081   46  7843   married       4422       no      no   no
# 37081        37082   56  1095   married      10229       no     yes   no
# 37082        37083   44  5720   married       4422       no      no   no
#
#              City_Name  State_Name  ... nr.employed    contact  month  \
# 0            Henderson    Kentucky  ...      5191.0  telephone    may
# 1            Henderson    Kentucky  ...      5191.0  telephone    may
# 2          Los Angeles  California  ...      5191.0  telephone    may
# 3      Fort Lauderdale     Florida  ...      5191.0  telephone    may
# 4      Fort Lauderdale     Florida  ...      5191.0  telephone    may
# ...                ...         ...  ...         ...        ...    ...
# 37077    New York City    New York  ...      4963.6   cellular    nov
# 37078    New York City    New York  ...      4963.6   cellular    nov
# 37080    New York City    New York  ...      4963.6   cellular    nov
# 37081    New York City    New York  ...      4963.6   cellular    nov
# 37082       Scottsdale     Arizona  ...      4963.6   cellular    nov
#
#        day_of_week  campaign  pdays previous     poutcome    y  \
# 0              mon         1      0        0  nonexistent   no
# 1              mon         1      0        0  nonexistent   no
# 2              mon         1      0        0  nonexistent   no
# 3              mon         1      0        0  nonexistent   no
# 4              mon         1      0        0  nonexistent   no
# ...            ...       ...    ...      ...          ...  ...
# 37077          fri         3      0        0  nonexistent   no
# 37078          fri         1      0        0  nonexistent  yes
# 37080          fri         1      0        0  nonexistent   no
# 37081          fri         2      0        0  nonexistent   no
# 37082          fri         1      0        0  nonexistent  yes
#
#        call_duration_segment
# 0                          3
# 1                          1
# 2                          1
# 3                          2
# 4                          3
# ...                      ...
# 37077                      1
# 37078                      2
# 37080                      3
# 37081                      1
# 37082                      4
#
# [34478 rows x 25 columns]

# %% [markdown]
# #### City

# %%
dataset_city=dataset['City_Name'].value_counts().to_dict()
dataset['City_Name']=dataset['City_Name'].map(dataset_city)

# %% [markdown]
# #### State

# %%
dataset_state=dataset['State_Name'].value_counts().to_dict()
dataset['State_Name']=dataset['State_Name'].map(dataset_state)

# %% [markdown]
# #### Region

# %%
dataset_region=dataset['Region_Name'].value_counts().to_dict()
dataset['Region_Name']=dataset['Region_Name'].map(dataset_region)

# %%
dataset
# Out:
#        Customer_id  age   job   marital  education  default housing loan  \
# 0                1   56  3332   married       8020       no      no  yes
# 1                2   45  3332   married      10380  unknown      no   no
# 2                3   59  8834   married       4422       no      no   no
# 3                4   41  7843   married       1413  unknown      no   no
# 4                5   24  5720    single       4422       no     yes   no
# ...            ...  ...   ...       ...        ...      ...     ...  ...
# 37077        37078   64  1095  divorced       4422       no     yes   no
# 37078        37079   37  8834   married      10229       no     yes   no
# 37080        37081   46  7843   married       4422       no      no   no
# 37081        37082   56  1095   married      10229       no     yes   no
# 37082        37083   44  5720   married       4422       no      no   no
#
#        City_Name  State_Name  ...  nr.employed    contact  month  day_of_week  \
# 0            183         487  ...       5191.0  telephone    may          mon
# 1            183         487  ...       5191.0  telephone    may          mon
# 2           2568        6867  ...       5191.0  telephone    may          mon
# 3             52        1317  ...       5191.0  telephone    may          mon
# 4             52        1317  ...       5191.0  telephone    may          mon
# ...          ...         ...  ...          ...        ...    ...          ...
# 37077       3167        3909  ...       4963.6   cellular    nov          fri
# 37078       3167        3909  ...       4963.6   cellular    nov          fri
# 37080       3167        3909  ...       4963.6   cellular    nov          fri
# 37081       3167        3909  ...       4963.6   cellular    nov          fri
# 37082         47         781  ...       4963.6   cellular    nov          fri
#
#        campaign  pdays previous     poutcome    y  call_duration_segment
# 0             1      0        0  nonexistent   no                      3
# 1             1      0        0  nonexistent   no                      1
# 2             1      0        0  nonexistent   no                      1
# 3             1      0        0  nonexistent   no                      2
# 4             1      0        0  nonexistent   no                      3
# ...         ...    ...      ...          ...  ...                    ...
# 37077         3      0        0  nonexistent   no                      1
# 37078         1      0        0  nonexistent  yes                      2
# 37080         1      0        0  nonexistent   no                      3
# 37081         2      0        0  nonexistent   no                      1
# 37082         1      0        0  nonexistent  yes                      4
#
# [34478 rows x 25 columns]

# %% [markdown]
# ### Label Encoding 'month', 'day_of_week', 'default', 'housing', 'loan'

# %% [markdown]
# #### Month

# %%
dataset['month'].value_counts()
# Out:
# may    11799
# jul     5780
# aug     5071
# jun     4340
# nov     3607
# apr     2292
# oct      566
# sep      451
# mar      431
# dec      141
# Name: month, dtype: int64

# %%
month_dict={'may':5,'jul':7,'aug':8,'jun':6,'nov':11,'apr':4,'oct':10,'sep':9,'mar':3,'dec':12}
dataset['month']= dataset['month'].map(month_dict)

# %% [markdown]
# #### Days Of Week

# %%
dataset['day_of_week'].value_counts()
# Out:
# mon    7186
# thu    7176
# wed    6858
# tue    6795
# fri    6463
# Name: day_of_week, dtype: int64

# %%
day_dict={'thu':5,'mon':2,'wed':4,'tue':3,'fri':6}
dataset['day_of_week']= dataset['day_of_week'].map(day_dict)

# %%
dataset
# Out:
#        Customer_id  age   job   marital  education  default housing loan  \
# 0                1   56  3332   married       8020       no      no  yes
# 1                2   45  3332   married      10380  unknown      no   no
# 2                3   59  8834   married       4422       no      no   no
# 3                4   41  7843   married       1413  unknown      no   no
# 4                5   24  5720    single       4422       no     yes   no
# ...            ...  ...   ...       ...        ...      ...     ...  ...
# 37077        37078   64  1095  divorced       4422       no     yes   no
# 37078        37079   37  8834   married      10229       no     yes   no
# 37080        37081   46  7843   married       4422       no      no   no
# 37081        37082   56  1095   married      10229       no     yes   no
# 37082        37083   44  5720   married       4422       no      no   no
#
#        City_Name  State_Name  ...  nr.employed    contact  month  day_of_week  \
# 0            183         487  ...       5191.0  telephone      5            2
# 1            183         487  ...       5191.0  telephone      5            2
# 2           2568        6867  ...       5191.0  telephone      5            2
# 3             52        1317  ...       5191.0  telephone      5            2
# 4             52        1317  ...       5191.0  telephone      5            2
# ...          ...         ...  ...          ...        ...    ...          ...
# 37077       3167        3909  ...       4963.6   cellular     11            6
# 37078       3167        3909  ...       4963.6   cellular     11            6
# 37080       3167        3909  ...       4963.6   cellular     11            6
# 37081       3167        3909  ...       4963.6   cellular     11            6
# 37082         47         781  ...       4963.6   cellular     11            6
#
#        campaign  pdays previous     poutcome    y  call_duration_segment
# 0             1      0        0  nonexistent   no                      3
# 1             1      0        0  nonexistent   no                      1
# 2             1      0        0  nonexistent   no                      1
# 3             1      0        0  nonexistent   no                      2
# 4             1      0        0  nonexistent   no                      3
# ...         ...    ...      ...          ...  ...                    ...
# 37077         3      0        0  nonexistent   no                      1
# 37078         1      0        0  nonexistent  yes                      2
# 37080         1      0        0  nonexistent   no                      3
# 37081         2      0        0  nonexistent   no                      1
# 37082         1      0        0  nonexistent  yes                      4
#
# [34478 rows x 25 columns]

# %% [markdown]
# #### Default

# %%
dataset['default'].value_counts()
# Out:
# no         27370
# unknown     7106
# yes            2
# Name: default, dtype: int64

# %%
dictionary={'yes':1,'no':0,'unknown':-1}
dataset['default']=dataset['default'].map(dictionary)

# %% [markdown]
# #### Housing

# %%
dataset['housing'].value_counts()
# Out:
# yes        18088
# no         15575
# unknown      815
# Name: housing, dtype: int64

# %%
dataset['housing']=dataset['housing'].map(dictionary)

# %% [markdown]
# #### Loan

# %%
dataset['loan'].value_counts()
# Out:
# no         28418
# yes         5245
# unknown      815
# Name: loan, dtype: int64

# %%
dataset['loan']=dataset['loan'].map(dictionary)

# %%
dataset
# Out:
#        Customer_id  age   job   marital  education  default  housing  loan  \
# 0                1   56  3332   married       8020        0        0     1
# 1                2   45  3332   married      10380       -1        0     0
# 2                3   59  8834   married       4422        0        0     0
# 3                4   41  7843   married       1413       -1        0     0
# 4                5   24  5720    single       4422        0        1     0
# ...            ...  ...   ...       ...        ...      ...      ...   ...
# 37077        37078   64  1095  divorced       4422        0        1     0
# 37078        37079   37  8834   married      10229        0        1     0
# 37080        37081   46  7843   married       4422        0        0     0
# 37081        37082   56  1095   married      10229        0        1     0
# 37082        37083   44  5720   married       4422        0        0     0
#
#        City_Name  State_Name  ...  nr.employed    contact  month  day_of_week  \
# 0            183         487  ...       5191.0  telephone      5            2
# 1            183         487  ...       5191.0  telephone      5            2
# 2           2568        6867  ...       5191.0  telephone      5            2
# 3             52        1317  ...       5191.0  telephone      5            2
# 4             52        1317  ...       5191.0  telephone      5            2
# ...          ...         ...  ...          ...        ...    ...          ...
# 37077       3167        3909  ...       4963.6   cellular     11            6
# 37078       3167        3909  ...       4963.6   cellular     11            6
# 37080       3167        3909  ...       4963.6   cellular     11            6
# 37081       3167        3909  ...       4963.6   cellular     11            6
# 37082         47         781  ...       4963.6   cellular     11            6
#
#        campaign  pdays previous     poutcome    y  call_duration_segment
# 0             1      0        0  nonexistent   no                      3
# 1             1      0        0  nonexistent   no                      1
# 2             1      0        0  nonexistent   no                      1
# 3             1      0        0  nonexistent   no                      2
# 4             1      0        0  nonexistent   no                      3
# ...         ...    ...      ...          ...  ...                    ...
# 37077         3      0        0  nonexistent   no                      1
# 37078         1      0        0  nonexistent  yes                      2
# 37080         1      0        0  nonexistent   no                      3
# 37081         2      0        0  nonexistent   no                      1
# 37082         1      0        0  nonexistent  yes                      4
#
# [34478 rows x 25 columns]

# %% [markdown]
# #### y

# %%
dataset['y'].value_counts()
# Out:
# no     30568
# yes     3910
# Name: y, dtype: int64

# %%
dictionary1={'no':0,'yes':1}
dataset['y']=dataset['y'].map(dictionary1)
dataset
# Out:
#        Customer_id  age   job   marital  education  default  housing  loan  \
# 0                1   56  3332   married       8020        0        0     1
# 1                2   45  3332   married      10380       -1        0     0
# 2                3   59  8834   married       4422        0        0     0
# 3                4   41  7843   married       1413       -1        0     0
# 4                5   24  5720    single       4422        0        1     0
# ...            ...  ...   ...       ...        ...      ...      ...   ...
# 37077        37078   64  1095  divorced       4422        0        1     0
# 37078        37079   37  8834   married      10229        0        1     0
# 37080        37081   46  7843   married       4422        0        0     0
# 37081        37082   56  1095   married      10229        0        1     0
# 37082        37083   44  5720   married       4422        0        0     0
#
#        City_Name  State_Name  ...  nr.employed    contact  month  day_of_week  \
# 0            183         487  ...       5191.0  telephone      5            2
# 1            183         487  ...       5191.0  telephone      5            2
# 2           2568        6867  ...       5191.0  telephone      5            2
# 3             52        1317  ...       5191.0  telephone      5            2
# 4             52        1317  ...       5191.0  telephone      5            2
# ...          ...         ...  ...          ...        ...    ...          ...
# 37077       3167        3909  ...       4963.6   cellular     11            6
# 37078       3167        3909  ...       4963.6   cellular     11            6
# 37080       3167        3909  ...       4963.6   cellular     11            6
# 37081       3167        3909  ...       4963.6   cellular     11            6
# 37082         47         781  ...       4963.6   cellular     11            6
#
#        campaign  pdays previous     poutcome  y  call_duration_segment
# 0             1      0        0  nonexistent  0                      3
# 1             1      0        0  nonexistent  0                      1
# 2             1      0        0  nonexistent  0                      1
# 3             1      0        0  nonexistent  0                      2
# 4             1      0        0  nonexistent  0                      3
# ...         ...    ...      ...          ... ..                    ...
# 37077         3      0        0  nonexistent  0                      1
# 37078         1      0        0  nonexistent  1                      2
# 37080         1      0        0  nonexistent  0                      3
# 37081         2      0        0  nonexistent  0                      1
# 37082         1      0        0  nonexistent  1                      4
#
# [34478 rows x 25 columns]

# %% [markdown]
# ### Mean Encoding 'marital' Based On Mean Of 'y'

# %%
dataset.groupby(['marital'])['y'].mean()
# Out:
# marital
# divorced    0.095657
# married     0.100460
# single      0.147275
# unknown     0.190476
# Name: y, dtype: float64

# %%
ordinal_labels=dataset.groupby(['marital'])['y'].mean().sort_values().index
ordinal_labels
# Out:
# Index(['divorced', 'married', 'single', 'unknown'], dtype='object', name='marital')

# %%
ordinal_labels2={k:i for i,k in enumerate(ordinal_labels,0)}
ordinal_labels2
# Out:
# {'divorced': 0, 'married': 1, 'single': 2, 'unknown': 3}

# %%
dataset['marital_ordinal']=dataset['marital'].map(ordinal_labels2)
dataset.drop(['marital'], axis=1,inplace=True)

# %%
dataset.marital_ordinal.value_counts()
# Out:
# 1    20864
# 2     9798
# 0     3753
# 3       63
# Name: marital_ordinal, dtype: int64

# %%
dataset
# Out:
#        Customer_id  age   job  education  default  housing  loan  City_Name  \
# 0                1   56  3332       8020        0        0     1        183
# 1                2   45  3332      10380       -1        0     0        183
# 2                3   59  8834       4422        0        0     0       2568
# 3                4   41  7843       1413       -1        0     0         52
# 4                5   24  5720       4422        0        1     0         52
# ...            ...  ...   ...        ...      ...      ...   ...        ...
# 37077        37078   64  1095       4422        0        1     0       3167
# 37078        37079   37  8834      10229        0        1     0       3167
# 37080        37081   46  7843       4422        0        0     0       3167
# 37081        37082   56  1095      10229        0        1     0       3167
# 37082        37083   44  5720       4422        0        0     0         47
#
#        State_Name  Region_Name  ...    contact  month  day_of_week  campaign  \
# 0             487         5594  ...  telephone      5            2         1
# 1             487         5594  ...  telephone      5            2         1
# 2            6867        11072  ...  telephone      5            2         1
# 3            1317         5594  ...  telephone      5            2         1
# 4            1317         5594  ...  telephone      5            2         1
# ...           ...          ...  ...        ...    ...          ...       ...
# 37077        3909         9837  ...   cellular     11            6         3
# 37078        3909         9837  ...   cellular     11            6         1
# 37080        3909         9837  ...   cellular     11            6         1
# 37081        3909         9837  ...   cellular     11            6         2
# 37082         781        11072  ...   cellular     11            6         1
#
#        pdays previous     poutcome  y  call_duration_segment  marital_ordinal
# 0          0        0  nonexistent  0                      3                1
# 1          0        0  nonexistent  0                      1                1
# 2          0        0  nonexistent  0                      1                1
# 3          0        0  nonexistent  0                      2                1
# 4          0        0  nonexistent  0                      3                2
# ...      ...      ...          ... ..                    ...              ...
# 37077      0        0  nonexistent  0                      1                0
# 37078      0        0  nonexistent  1                      2                1
# 37080      0        0  nonexistent  0                      3                1
# 37081      0        0  nonexistent  0                      1                1
# 37082      0        0  nonexistent  1                      4                1
#
# [34478 rows x 25 columns]

# %% [markdown]
# ### Encoding 'poutcome' And 'contact' Using Pandas

# %%
dataset['poutcome'].value_counts()
# Out:
# nonexistent    29692
# failure         3645
# success         1141
# Name: poutcome, dtype: int64

# %%
dataset['contact'].value_counts()
# Out:
# cellular     22001
# telephone    12477
# Name: contact, dtype: int64

# %%
Contact=pd.get_dummies(dataset['contact'], prefix='contact',drop_first=True)
Outcome=pd.get_dummies(dataset['poutcome'], prefix='poutcome',drop_first=True)
dataset = pd.concat([dataset,Contact,Outcome],axis=1)
dataset.drop(['contact','poutcome'],axis=1, inplace=True)

# %%
dataset
# Out:
#        Customer_id  age   job  education  default  housing  loan  City_Name  \
# 0                1   56  3332       8020        0        0     1        183
# 1                2   45  3332      10380       -1        0     0        183
# 2                3   59  8834       4422        0        0     0       2568
# 3                4   41  7843       1413       -1        0     0         52
# 4                5   24  5720       4422        0        1     0         52
# ...            ...  ...   ...        ...      ...      ...   ...        ...
# 37077        37078   64  1095       4422        0        1     0       3167
# 37078        37079   37  8834      10229        0        1     0       3167
# 37080        37081   46  7843       4422        0        0     0       3167
# 37081        37082   56  1095      10229        0        1     0       3167
# 37082        37083   44  5720       4422        0        0     0         47
#
#        State_Name  Region_Name  ...  day_of_week  campaign  pdays  previous  \
# 0             487         5594  ...            2         1      0         0
# 1             487         5594  ...            2         1      0         0
# 2            6867        11072  ...            2         1      0         0
# 3            1317         5594  ...            2         1      0         0
# 4            1317         5594  ...            2         1      0         0
# ...           ...          ...  ...          ...       ...    ...       ...
# 37077        3909         9837  ...            6         3      0         0
# 37078        3909         9837  ...            6         1      0         0
# 37080        3909         9837  ...            6         1      0         0
# 37081        3909         9837  ...            6         2      0         0
# 37082         781        11072  ...            6         1      0         0
#
#        y  call_duration_segment  marital_ordinal  contact_telephone  \
# 0      0                      3                1                  1
# 1      0                      1                1                  1
# 2      0                      1                1                  1
# 3      0                      2                1                  1
# 4      0                      3                2                  1
# ...   ..                    ...              ...                ...
# 37077  0                      1                0                  0
# 37078  1                      2                1                  0
# 37080  0                      3                1                  0
# 37081  0                      1                1                  0
# 37082  1                      4                1                  0
#
#        poutcome_nonexistent  poutcome_success
# 0                         1                 0
# 1                         1                 0
# 2                         1                 0
# 3                         1                 0
# 4                         1                 0
# ...                     ...               ...
# 37077                     1                 0
# 37078                     1                 0
# 37080                     1                 0
# 37081                     1                 0
# 37082                     1                 0
#
# [34478 rows x 26 columns]

# %% [markdown]
# ## Scaling The Features

# %%
from sklearn.preprocessing import StandardScaler

dataset_scale=dataset.copy()
Categorical_variables=['job', 'education', 'default', 'housing', 'loan', 'month',
       'day_of_week','y', 'contact_telephone', 'poutcome_nonexistent',
       'poutcome_success', 'marital_ordinal']


feature_scale=[feature for feature in dataset_scale.columns if feature not in Categorical_variables]


scaler=StandardScaler()
scaler.fit(dataset_scale[feature_scale])
# Out:
# StandardScaler()

# %%
scaled_dataset = pd.concat([dataset_scale[['job', 'education', 'default', 'housing', 'loan', 'month',
       'day_of_week','y', 'contact_telephone', 'poutcome_nonexistent',
       'poutcome_success', 'marital_ordinal']].reset_index(drop=True),
                    pd.DataFrame(scaler.transform(dataset_scale[feature_scale]), columns=feature_scale)],
                    axis=1)
scaled_dataset
# Out:
#         job  education  default  housing  loan  month  day_of_week  y  \
# 0      3332       8020        0        0     1      5            2  0
# 1      3332      10380       -1        0     0      5            2  0
# 2      8834       4422        0        0     0      5            2  0
# 3      7843       1413       -1        0     0      5            2  0
# 4      5720       4422        0        1     0      5            2  0
# ...     ...        ...      ...      ...   ...    ...          ... ..
# 34473  1095       4422        0        1     0     11            6  0
# 34474  8834      10229        0        1     0     11            6  1
# 34475  7843       4422        0        0     0     11            6  0
# 34476  1095      10229        0        1     0     11            6  0
# 34477  5720       4422        0        0     0     11            6  1
#
#        contact_telephone  poutcome_nonexistent  ...  Region_Name  \
# 0                      1                     1  ...    -1.832520
# 1                      1                     1  ...    -1.832520
# 2                      1                     1  ...     1.018947
# 3                      1                     1  ...    -1.832520
# 4                      1                     1  ...    -1.832520
# ...                  ...                   ...  ...          ...
# 34473                  0                     1  ...     0.376091
# 34474                  0                     1  ...     0.376091
# 34475                  0                     1  ...     0.376091
# 34476                  0                     1  ...     0.376091
# 34477                  0                     1  ...     1.018947
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# 0          0.661363        0.739181       0.900020   0.721331     0.340460
# 1          0.661363        0.739181       0.900020   0.721331     0.340460
# 2          0.661363        0.739181       0.900020   0.721331     0.340460
# 3          0.661363        0.739181       0.900020   0.721331     0.340460
# 4          0.661363        0.739181       0.900020   0.721331     0.340460
# ...             ...             ...            ...        ...          ...
# 34473     -0.745439        2.081250      -2.221779  -1.490161    -2.837318
# 34474     -0.745439        2.081250      -2.221779  -1.490161    -2.837318
# 34475     -0.745439        2.081250      -2.221779  -1.490161    -2.837318
# 34476     -0.745439        2.081250      -2.221779  -1.490161    -2.837318
# 34477     -0.745439        2.081250      -2.221779  -1.490161    -2.837318
#
#        campaign     pdays  previous  call_duration_segment
# 0     -0.816947 -0.162487 -0.353135               0.418254
# 1     -0.816947 -0.162487 -0.353135              -0.470341
# 2     -0.816947 -0.162487 -0.353135              -0.470341
# 3     -0.816947 -0.162487 -0.353135              -0.026043
# 4     -0.816947 -0.162487 -0.353135               0.418254
# ...         ...       ...       ...                    ...
# 34473  0.744530 -0.162487 -0.353135              -0.470341
# 34474 -0.816947 -0.162487 -0.353135              -0.026043
# 34475 -0.816947 -0.162487 -0.353135               0.418254
# 34476 -0.036209 -0.162487 -0.353135              -0.470341
# 34477 -0.816947 -0.162487 -0.353135               0.862551
#
# [34478 rows x 26 columns]

# %%
correlation_matrix = scaled_dataset.corr()

plt.figure(figsize=(16, 14))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Building The Model Using All Features

# %%
from sklearn.linear_model import LogisticRegression
y=scaled_dataset['y']
X=scaled_dataset.drop(['y', 'Customer_id'],axis=1)

model = LogisticRegression(max_iter = 1000)
model.fit(X,y)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### Displaying The Contribution Of Each Feature Towards The Model

# %%
# Get feature names
feature_names = X.columns

# Get coefficients
coefficients = model.coef_[0]

feature_importance = pd.DataFrame({
    'Feature': feature_names,
    'Coefficient': coefficients
})

# Sort by absolute value of coefficients to see most important features
feature_importance['Absolute Coefficient'] = np.abs(feature_importance['Coefficient'])
feature_importance = feature_importance.sort_values(by='Absolute Coefficient', ascending=False)

# Display feature importance
print(feature_importance)
# Out:
#                   Feature  Coefficient  Absolute Coefficient
# 23  call_duration_segment     1.257282              1.257282
# 19            nr.employed    -0.541601              0.541601
# 15           emp.var.rate    -0.341538              0.341538
# 17          cons.conf.idx     0.328941              0.328941
# 18              euribor3m    -0.310680              0.310680
# 7       contact_telephone    -0.263824              0.263824
# 2                 default     0.177832              0.177832
# 21                  pdays     0.165199              0.165199
# 6             day_of_week    -0.134645              0.134645
# 9        poutcome_success     0.133646              0.133646
# 5                   month    -0.120833              0.120833
# 8    poutcome_nonexistent    -0.109129              0.109129
# 16         cons.price.idx     0.082139              0.082139
# 10        marital_ordinal    -0.079774              0.079774
# 20               campaign    -0.077775              0.077775
# 3                 housing    -0.067650              0.067650
# 11                    age    -0.066858              0.066858
# 22               previous    -0.045767              0.045767
# 4                    loan    -0.021963              0.021963
# 12              City_Name     0.018628              0.018628
# 14            Region_Name     0.003776              0.003776
# 13             State_Name     0.003131              0.003131
# 1               education    -0.000105              0.000105
# 0                     job    -0.000057              0.000057

# %% [markdown]
# ### Filtering Out Only The Top 15 Features

# %%
# Display the top 15 features
top_15_features = feature_importance.head(15)
print("Top 15 Features:")
print(top_15_features)

# Get the list of top 15 feature names
top_15_feature_names = top_15_features['Feature'].tolist()

# Create a new dataset with only top 15 features
X_top_15 = X[top_15_feature_names]
X=X_top_15
# Out:
# Top 15 Features:
#                   Feature  Coefficient  Absolute Coefficient
# 23  call_duration_segment     1.257282              1.257282
# 19            nr.employed    -0.541601              0.541601
# 15           emp.var.rate    -0.341538              0.341538
# 17          cons.conf.idx     0.328941              0.328941
# 18              euribor3m    -0.310680              0.310680
# 7       contact_telephone    -0.263824              0.263824
# 2                 default     0.177832              0.177832
# 21                  pdays     0.165199              0.165199
# 6             day_of_week    -0.134645              0.134645
# 9        poutcome_success     0.133646              0.133646
# 5                   month    -0.120833              0.120833
# 8    poutcome_nonexistent    -0.109129              0.109129
# 16         cons.price.idx     0.082139              0.082139
# 10        marital_ordinal    -0.079774              0.079774
# 20               campaign    -0.077775              0.077775

# %% [markdown]
# ## Splitting The Dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,train_size=0.8,random_state=1)
print("Input Training:",X_train.shape)
print("Input Test:",X_test.shape)
print("Output Training:",y_train.shape)
print("Output Test:",y_test.shape)
# Out:
# Input Training: (27582, 15)
# Input Test: (6896, 15)
# Output Training: (27582,)
# Output Test: (6896,)

# %% [markdown]
# ## Logistic Regression

# %%
model1 = LogisticRegression(max_iter=1000)
model1.fit(X_train, y_train)
y_pred = model1.predict(X_test)
acc = model1.score(X_test,y_test)
print(f"Accuracy : {acc}")
# Out:
# Accuracy : 0.9177784222737819

# %%
print('Classification Report')
print(classification_report(y_test, y_pred))
print()

print('Confusion Matrix')
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95      6153
#            1       0.67      0.47      0.55       743
#
#     accuracy                           0.92      6896
#    macro avg       0.80      0.72      0.75      6896
# weighted avg       0.91      0.92      0.91      6896
#
#
# Confusion Matrix
# [[5980  173]
#  [ 394  349]]

# %%
# Get predicted probabilities for the positive class
y_prob = model1.predict_proba(X_test)[:, 1]

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = roc_auc_score(y_test, y_prob)

# Plot ROC curve
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
